# %%
from mpc_nn_model import *
from platform import python_version

print(python_version())
# Out:
# 3.8.8

# %%
####### Initialize Parameters #######
n_epochs=120
min_timesteps=50
n_rollout=10
n_skips_per_rollout=0
n_test=1
n_input=6
n_output=n_rollout*3 # 3 for each of the next n_rollout time steps
n_state_enc=4
learning_rate=0.0003
gen_model=1
pred_model=1
device = torch.device("cpu")

## Load the network ##
mpc_nn_predictor=MPC_NN_Predictor(n_epochs,min_timesteps,n_rollout,n_skips_per_rollout,n_test,n_input,n_output,n_state_enc,learning_rate,gen_model,pred_model,device)
mpc_nn_predictor.load_model_weights("encoder_rnn_decoder_simple_nn_n_rollout_n_skips_MSELOSS")


## time_step=0 - beginning timestep

latest_observation=[-50.0, -55.07154566354707, 10.0, 7.640203465650082]
previous_action=[0, 0]
ais_encoder_previous=0

nn_prediction,ais_encoder_previous=mpc_nn_predictor.nn_prediction_model(latest_observation,previous_action,ais_encoder_previous=torch.tensor([0.5]),time_step=0)

'''
## These are the reference and the prediction for the input used in this example

reference_tensor:  tensor([-5.3544e+01,  7.6373e+00, -1.4631e-02, -5.2017e+01,  7.6342e+00,
        -1.5143e-02, -5.0490e+01,  7.6311e+00, -1.5625e-02, -4.8964e+01,
         7.6279e+00, -1.6155e-02, -4.7439e+01,  7.6245e+00, -1.6715e-02,
        -4.5914e+01,  7.6211e+00, -1.7306e-02, -4.4391e+01,  7.6175e+00,
        -1.7929e-02, -4.2867e+01,  7.6138e+00, -1.8585e-02, -4.1345e+01,
         7.6099e+00, -1.9274e-02, -3.9823e+01,  7.6059e+00, -1.9998e-02])
decoder_prediction:  tensor([-54.3219,   8.9352,   0.6506, -52.5406,   9.0583,   0.5747, -50.7522,
          9.1472,   0.4971, -48.9095,   9.2151,   0.4208, -47.0374,   9.2986,
          0.3441, -45.1749,   9.3496,   0.3049, -43.3091,   9.3803,   0.2646,
        -41.4378,   9.4326,   0.1963, -39.5321,   9.4583,   0.1659, -37.6572,
          9.4721,   0.1397], grad_fn=<AddBackward0>)
'''

print("nn_prediction",nn_prediction)


## time_step=1

latest_observation=[-48.1, -53.54379758868027, 9.0, 7.637277283017936]
previous_action=[-5.0, -0.014630913160728388]

nn_prediction,ais_encoder_previous=mpc_nn_predictor.nn_prediction_model(latest_observation,previous_action,ais_encoder_previous,time_step=1)

'''
## These are the reference and the prediction for the input used in this example
reference_tensor: [-5.2017e+01,  7.6342e+00, -1.5143e-02, -5.0490e+01,  7.6311e+00,
        -1.5625e-02, -4.8964e+01,  7.6279e+00, -1.6155e-02, -4.7439e+01,
         7.6245e+00, -1.6715e-02, -4.5914e+01,  7.6211e+00, -1.7306e-02,
        -4.4391e+01,  7.6175e+00, -1.7929e-02, -4.2867e+01,  7.6138e+00,
        -1.8585e-02, -4.1345e+01,  7.6099e+00, -1.9274e-02, -3.9823e+01,
         7.6059e+00, -1.9998e-02, -3.8303e+01,  7.6018e+00, -2.0753e-02]

decoder_prediction:[-51.9450,   7.1727,   0.5624, -50.5234,   7.2903,   0.5072, -49.0496,
          7.3674,   0.4431, -47.5563,   7.4702,   0.3935, -46.0516,   7.5254,
          0.3404, -44.5402,   7.5749,   0.3076, -43.0161,   7.6296,   0.2759,
        -41.4827,   7.6741,   0.2346, -39.9520,   7.7092,   0.2103, -38.4100,
          7.7451,   0.1876]
'''

print("nn_prediction",nn_prediction)



## time_step=2

latest_observation=[-46.4, -52.016644997418624, 8.0, 7.634248629598489]
previous_action=[-5.0, -0.015143267097237196]

nn_prediction,ais_encoder_previous=mpc_nn_predictor.nn_prediction_model(latest_observation,previous_action,ais_encoder_previous,time_step=2)


'''
reference_tensor:  tensor([-5.0490e+01,  7.6311e+00, -1.5625e-02, -4.8964e+01,  7.6279e+00,
        -1.6155e-02, -4.7439e+01,  7.6245e+00, -1.6715e-02, -4.5914e+01,
         7.6211e+00, -1.7306e-02, -4.4391e+01,  7.6175e+00, -1.7929e-02,
        -4.2867e+01,  7.6138e+00, -1.8585e-02, -4.1345e+01,  7.6099e+00,
        -1.9274e-02, -3.9823e+01,  7.6059e+00, -1.9998e-02, -3.8303e+01,
         7.6018e+00, -2.0753e-02, -3.6783e+01,  7.5975e+00, -2.1535e-02])
decoder_prediction:  tensor([-50.7259,   7.4227,   0.5537, -49.2502,   7.5371,   0.4973, -47.7292,
          7.6152,   0.4340, -46.1875,   7.7143,   0.3845, -44.6358,   7.7692,
          0.3329, -43.0758,   7.8183,   0.2997, -41.5026,   7.8719,   0.2684,
        -39.9210,   7.9145,   0.2293, -38.3420,   7.9491,   0.2054, -36.7511,
          7.9838,   0.1833], grad_fn=<AddBackward0>)
'''

print("nn_prediction",nn_prediction)


########### To convert the tensor to a list/ array we can use ##############

nn_prediction.detach().cpu().numpy().tolist()

########## NOTE- I suggest that we do not convert the ais_encoder_previous to a list/array. ##############
# Out:
# names of files-Encoder ../trained_models/IRL_based_models/IRL_SVOpolicy_ais_gen1_816_pred1_24_epochs120_learning_rate0.0003_hidden_states4encoder_rnn_decoder_simple_nn_n_rollout_n_skips_MSELOSS.pth
#
# names of files-Decoder ../trained_models/IRL_based_models/IRL_SVOpolicy_ais_pred1_24_gen1_816_epochs120_learning_rate0.0003_hidden_states4encoder_rnn_decoder_simple_nn_n_rollout_n_skips_MSELOSS.pth
#
# nn_prediction tensor([-54.3219,   8.9352,   0.6506, -52.5406,   9.0583,   0.5747, -50.7522,
#           9.1472,   0.4971, -48.9095,   9.2151,   0.4208, -47.0374,   9.2986,
#           0.3441, -45.1749,   9.3496,   0.3049, -43.3091,   9.3803,   0.2646,
#         -41.4378,   9.4326,   0.1963, -39.5321,   9.4583,   0.1659, -37.6572,
#           9.4721,   0.1397], grad_fn=<AddBackward0>)
# nn_prediction tensor([-51.9450,   7.1727,   0.5624, -50.5234,   7.2903,   0.5072, -49.0496,
#           7.3674,   0.4431, -47.5563,   7.4702,   0.3935, -46.0516,   7.5254,
#           0.3404, -44.5402,   7.5749,   0.3076, -43.0161,   7.6296,   0.2759,
#         -41.4827,   7.6741,   0.2346, -39.9520,   7.7092,   0.2103, -38.4100,
#           7.7451,   0.1876], grad_fn=<AddBackward0>)
# nn_prediction tensor([-50.7259,   7.4227,   0.5537, -49.2502,   7.5371,   0.4973, -47.7292,
#           7.6152,   0.4340, -46.1875,   7.7143,   0.3845, -44.6358,   7.7692,
#           0.3329, -43.0758,   7.8183,   0.2997, -41.5026,   7.8719,   0.2684,
#         -39.9210,   7.9145,   0.2293, -38.3420,   7.9491,   0.2054, -36.7511,
#           7.9838,   0.1833], grad_fn=<AddBackward0>)
# [-50.72589874267578,
#  7.422728538513184,
#  0.553703784942627,
#  -49.250221252441406,
#  7.537091255187988,
#  0.497339129447937,
#  -47.72918701171875,
#  7.615155220031738,
#  0.4339926540851593,
#  -46.18746566772461,
#  7.714254379272461,
#  0.3844726085662842,
#  -44.63575744628906,
#  7.769167423248291,
#  0.33288395404815674,
#  -43.075809478759766,
#  7.818282127380371,
#  0.2997094690799713,
#  -41.502628326416016,
#  7.8719048500061035,
#  0.2683604955673218,
#  -39.921016693115234,
#  7.9144673347473145,
#  0.22930794954299927,
#  -38.3420295715332,
#  7.949097633361816,
#  0.20540547370910645,
#  -36.751121520996094,
#  7.983842849731445,
#  0.18329846858978271]

# %%
import numpy as np
import matplotlib.pyplot as plt
import csv
import numpy.linalg as LA
from scipy.integrate import odeint
from timeit import default_timer as timer
from scipy.optimize import fmin, minimize

# %%
import sys
if sys.platform == 'win32' or sys.platform == 'win64': # Change to suit the OS
    sys.path.append(r"C:\Users\nish\Documents\casadi-windows-py39-v3.5.5-64bit")
else:
     sys.path.append(r"casadiinstalldir")

# %%
print(sys.path)
# Out:
# ['c:\\Users\\nish\\Documents\\GitHub\\CDC2023\\mpc_nn_files', 'c:\\Users\\nish\\Anaconda3\\python38.zip', 'c:\\Users\\nish\\Anaconda3\\DLLs', 'c:\\Users\\nish\\Anaconda3\\lib', 'c:\\Users\\nish\\Anaconda3', '', 'c:\\Users\\nish\\Anaconda3\\lib\\site-packages', 'c:\\Users\\nish\\Anaconda3\\lib\\site-packages\\win32', 'c:\\Users\\nish\\Anaconda3\\lib\\site-packages\\win32\\lib', 'c:\\Users\\nish\\Anaconda3\\lib\\site-packages\\Pythonwin', 'C:\\Users\\nish\\Documents\\casadi-windows-py39-v3.5.5-64bit', 'C:\\Users\\nish\\Documents\\casadi-windows-py39-v3.5.5-64bit', 'C:\\Users\\nish\\Documents\\casadi-windows-py39-v3.5.5-64bit', 'C:\\Users\\nish\\Documents\\casadi-windows-py39-v3.5.5-64bit', 'C:\\Users\\nish\\Documents\\casadi-windows-py39-v3.5.5-64bit', 'C:\\Users\\nish\\Documents\\casadi-windows-py38-v3.5.5-64bit', 'C:\\Users\\nish\\Documents\\casadi-windows-py39-v3.5.5-64bit', 'C:\\Users\\nish\\Documents\\casadi-windows-py39-v3.5.5-64bit']

# %%
import casadi as ca

# %% [markdown]
# ## CFM Model

# %%
def sigmoid(x):
    return 1/(1 + np.exp(-x))

def sigmoid_der(x):
    return sigmoid(x)*(1-sigmoid(x))

## This class is to compute the action of the human driver by IRL model
def IRL_CFM(p2_0, v2_0, p1_0, v1_0, u1_0, W, T = .2, v_max = 15., r = 0.):
        # Note that p2_0 and p1_0 should be the distance to the conflict point
        C = np.zeros(7)
        C[0] = W[0] + W[1]*T**2
        C[1] = 2*W[1]*(v2_0-v_max)*T
        C[2] = W[1]*(v2_0-v_max)**2
        C[3] = W[2]
        C[4] = (0.5*T**2)**2
        C[5] = 2*0.5*T**2*(p2_0+T*v2_0)
        C[6] = ((p1_0+v1_0*T)**2+(p2_0+v2_0*T)**2-r**2)  
        
        coeff = [(2*C[0]*C[4]), (C[1]*C[4]+2*C[0]*C[4]), (C[1]*C[5]+2*C[0]*C[6]-2*C[3]*C[4]), \
                  (C[1]*C[6]-C[3]*C[5])]
        root = np.roots(coeff)
        sol = np.real(root[np.isreal(root)])[0]
        return sol

# %%
class Vehicle:
    
    def __init__(self, p0, v0, bounds, T, Ts):
        self.p = p0; self.v = v0
        self.state = np.array([p0, v0])
        self.u = 0.0
        self.T = T; self.Ts = Ts
        self.X_hist = np.empty([2,0], dtype=np.ndarray)
        self.U_hist = np.empty([0], dtype=float)
        self.T_hist = np.empty([0], dtype=float)
        self.X_hist = np.hstack([self.X_hist, self.state.reshape([-1,1])])
        self.v_min = bounds['v_min'] + 1e-2; self.v_max = bounds['v_max'] - 1e-2
        self.u_min = bounds['u_min']; self.u_max = bounds['u_max']
        self.CFM_params = np.array([0.8, 1.2, 2.0, 20.0, 5.0])
        
    def double_integrator(self, z, t, u):
        v = z[1]
        dz = np.zeros(2)
        dz[0] = v; dz[1] = u
        return dz
    
    def run(self, u, time_stamp):    
        u = max(self.u_min, min(self.u_max, u)) # Control input should be saturated
        u = max(u, (self.v_min - self.v)/self.Ts)
        # u = min(u, (self.v_max - self.v)/self.Ts)
            
        tspan = np.linspace(0, self.Ts, 3)
        y = odeint(self.double_integrator, self.state, tspan, args=(u,)) 
        self.state = y[-1,]
        self.p, self.v = self.state
        self.u = u

    def save_data(self, time_stamp):
        self.X_hist = np.hstack([self.X_hist, self.state.reshape([-1,1])])
        self.U_hist = np.hstack([self.U_hist, self.u])  
        self.T_hist = np.hstack([self.T_hist, time_stamp])  

    def print(self, i):
        print("Some information for vehicle", i, ":", self.p, self.v)
    
    def const_U(self, U, t):
        time = np.arange(t, t+self.T, self.Ts)
        for k in time:
            self.run(U, k)  
        self.save_data(t+self.T)
        
    def const_V(self, V, t):
        time = np.arange(t, t+self.T, self.Ts)
        for k in time:
            U = (V-self.v)/self.Ts
            self.run(U, k)  
        self.save_data(t+self.T)

# %%
class CAV(Vehicle):
    
    def __init__(self, p0, v0, bounds, T, Ts):
        super().__init__(p0, v0, bounds, T, Ts)
        self.type = "CAV" # of course

# %%
class HDV(Vehicle):
    
    def __init__(self, p0, v0, bounds, T, Ts):
        super().__init__(p0, v0, bounds, T, Ts)
        self.type = "HDV" # of course

    def IRL(self, CAV_state, Q):
        p = self.p; v = self.v

        u = IRL_CFM(p, v, CAV_state[0], CAV_state[1], 0.0, Q, self.T, self.v_max, 0.0)
            
        u = max(self.u_min, min(self.u_max, u))
        if v + self.T*u < self.v_min:
            u = (self.v_min-v)/self.T
#         elif v + self.T*u > self.v_max:
#             u = (self.v_max-v)/self.T
        return u

# %%
class MPC:
    
    def __init__(self, H, T, bounds):
        self.H = H; self.T = T
        self.u_min = bounds['u_min']; self.u_max = bounds['u_max']
        self.v_min = bounds['v_min']; self.v_max = bounds['v_max']

    def set_state(self, st):
        self.state = st
        
    def set_road_info(self, r):
        self.r = r
        
    def set_weight(self, W1, W12):
        self.W1 = W1; self.W12 = W12
        
    def formulateMPC(self):
        # Create MPC optimizer
        self.mpc_opti = ca.Opti()
        
        # Variables for CAV
        self.U = self.mpc_opti.variable(self.H)
        self.V = self.mpc_opti.variable(self.H)
        self.P = self.mpc_opti.variable(self.H)
            
        self.X0 = self.mpc_opti.parameter(2) # initial condition of CAV state
        self.PH = self.mpc_opti.parameter(self.H) # the positions of the HDV over the horizon
        self.VH = self.mpc_opti.parameter(self.H) # the speeds of the HDV over the horizon

        # Objective function
        self.J = 0
        for k in range(self.H):
            self.J += self.W1[0]*self.U[k]**2 + self.W1[1]*(self.V[k] - self.v_max)**2
            self.J += -self.W12*ca.log((self.P[k]+0.5*self.V[k])**2 + (self.PH[k]+0.5*self.VH[k])**2 + 1e-6) 
        
        self.mpc_opti.minimize(self.J) 
        
        # Dynamics
        for k in range(self.H):
            if k == 0:
                self.mpc_opti.subject_to(self.P[k] == self.X0[0] + self.T*self.X0[1] \
                                            + 0.5*self.T**2*self.U[k])
                self.mpc_opti.subject_to(self.V[k] == self.X0[1] + self.T*self.U[k])            
            else:
                self.mpc_opti.subject_to(self.P[k] == self.P[k-1] + self.T*self.V[k-1] \
                                            + 0.5*self.T**2*self.U[k])
                self.mpc_opti.subject_to(self.V[k] == self.V[k-1] + self.T*self.U[k])
            
         # Constraints
        self.mpc_opti.subject_to(self.v_min <= self.V)
        self.mpc_opti.subject_to(self.V <= self.v_max)
        self.mpc_opti.subject_to(self.u_min <= self.U)
        self.mpc_opti.subject_to(self.U <= self.u_max)
        # self.D = (self.P+1.0*self.V)**2 + (self.PH+1.0*self.VH)**2 
        # self.mpc_opti.subject_to(self.r**2 <= self.D)
        
        p_opts = {'verbose_init': False}
        s_opts = {'tol': 0.001, 'print_level': 0, 'max_iter': 100}
        self.mpc_opti.solver('ipopt', p_opts, s_opts)

        # Warm up
        self.mpc_opti.set_value(self.X0, self.state)
        self.mpc_opti.set_value(self.PH, np.zeros(self.H))
        self.mpc_opti.set_value(self.VH, np.zeros(self.H))
         
        try:
            sol = self.mpc_opti.solve()
            
        except RuntimeError:
            print("An exception occurred")
            self.mpc_opti.set_initial(self.U, self.mpc_opti.debug.value(self.U))
        else:
            self.mpc_opti.set_initial(self.U, sol.value(self.U))
            self.mpc_opti.set_initial(self.V, sol.value(self.V))
            self.mpc_opti.set_initial(self.P, sol.value(self.P))
        
    def solveMPC(self, PH, VH):
        self.mpc_opti.set_value(self.X0, self.state)
        self.mpc_opti.set_value(self.PH, PH)
        self.mpc_opti.set_value(self.VH, VH)

        try:
            sol = self.mpc_opti.solve()
        except RuntimeError:
            print("An exception occurred")
            self.u = self.mpc_opti.debug.value(self.U)
        else:
            self.u = sol.value(self.U)
            self.mpc_opti.set_initial(self.U, np.hstack((sol.value(self.U)[1:], sol.value(self.U)[-1:])))    
            self.mpc_opti.set_initial(self.V, np.hstack((sol.value(self.V)[1:], sol.value(self.V)[-1:])))    
            self.mpc_opti.set_initial(self.P, np.hstack((sol.value(self.P)[1:], sol.value(self.P)[-1:])))    
                      
        return self.u[0]

# %% [markdown]
# ## Main simulation

# %%
np.random.seed(28)
T = 0.2; H = 10; Ts = 0.02
bounds = {'v_min' : 0.0, 'v_max' : 14.0, 'u_min' : -3.0, 'u_max' : 2.0}
r = 10.0 

Cars = []
Cars.append(CAV(-72.0, 10.4, bounds, T, Ts))
Cars.append(HDV(-70.0, 9.9, bounds, T, Ts))

control = MPC(H, T, bounds)
control.set_road_info(r)
control.set_state(Cars[0].state)
W1 = np.array([1e0,1e1])
W2 = np.array([1e-2,1e0]); W12 = 1e3
control.set_weight(W1, W12)
control.formulateMPC()
latest_observation=[Cars[0].p, Cars[1].p, Cars[0].v, Cars[1].v]
previous_action=[Cars[0].u, Cars[1].u]
ais_encoder_previous=0

Cars[0].const_U(0.0, 0.0)
Cars[1].const_U(Cars[1].IRL(Cars[0].state, np.hstack([W2, W12])), 0.0)

nn_prediction,ais_encoder_previous=mpc_nn_predictor.nn_prediction_model(latest_observation,previous_action,ais_encoder_previous=torch.tensor([0.5]),time_step=0)
# Out:
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  | 885.00us ( 40.23us)   1.02ms ( 46.34us)        22
#        nlp_g  | 818.00us ( 37.18us) 805.18us ( 36.60us)        22
#     nlp_grad  | 118.00us (118.00us) 116.72us (116.72us)         1
#   nlp_grad_f  |   1.03ms ( 44.91us)   1.09ms ( 47.49us)        23
#   nlp_hess_l  |   1.58ms ( 75.29us)   1.67ms ( 79.47us)        21
#    nlp_jac_g  |   1.04ms ( 45.35us)   1.06ms ( 45.98us)        23
#        total  |  28.90ms ( 28.90ms)  29.69ms ( 29.69ms)         1

# %%
L = 100 # number of simulation steps

for k in range(L):
    t = (k+1)*T
    print("Time %s" %t)
    control.set_state(Cars[0].state)
    
    latest_observation=[Cars[0].p, Cars[1].p, Cars[0].v, Cars[1].v]
    previous_action=[Cars[0].u, Cars[1].u]

    nn_prediction,ais_encoder_previous=mpc_nn_predictor.nn_prediction_model(latest_observation,previous_action,ais_encoder_previous,time_step=1)
    prediction = nn_prediction.detach().cpu().numpy()
    prediction = prediction.reshape([3,-1], order = 'F')
    print(Cars[1].p, prediction[0,0])
    PH = np.hstack([(Cars[1].p + prediction[0,0])/2, prediction[0,:-1]])
    VH = np.hstack([(Cars[1].v + prediction[1,0])/2, prediction[1,:-1]])
    u1 = control.solveMPC(PH, VH)
    u2 = Cars[1].IRL(Cars[0].state, np.hstack([W2, W12]))
    U = [u1, u2]
    Cars[0].const_U(u1, t)
    Cars[1].const_U(u2, t)

    if Cars[0].p > 0.0 and Cars[1].p > 0.0:
        break
# Out:
# Time 0.2
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  | 200.00us ( 25.00us) 201.18us ( 25.15us)         8
#        nlp_g  | 212.00us ( 26.50us) 214.02us ( 26.75us)         8
#     nlp_grad  |  95.00us ( 95.00us)  94.65us ( 94.65us)         1
#   nlp_grad_f  | 285.00us ( 31.67us) 297.84us ( 33.09us)         9
#   nlp_hess_l  | 483.00us ( 69.00us) 494.19us ( 70.60us)         7
#    nlp_jac_g  | 328.00us ( 36.44us) 370.08us ( 41.12us)         9
#        total  |   8.89ms (  8.89ms)   9.25ms (  9.25ms)         1
# Time 0.4
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  | 210.00us ( 35.00us) 213.03us ( 35.51us)         6
#        nlp_g  | 210.00us ( 35.00us) 207.27us ( 34.54us)         6
#     nlp_grad  |  95.00us ( 95.00us)  96.34us ( 96.34us)         1
#   nlp_grad_f  | 271.00us ( 38.71us) 272.12us ( 38.87us)         7
#   nlp_hess_l  | 311.00us ( 62.20us) 324.58us ( 64.92us)         5
#    nlp_jac_g  | 314.00us ( 44.86us) 312.88us ( 44.70us)         7
#        total  |   7.51ms (  7.51ms)   8.49ms (  8.49ms)         1
# Time 0.6000000000000001
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  | 210.00us ( 35.00us) 209.48us ( 34.91us)         6
#        nlp_g  | 215.00us ( 35.83us) 214.20us ( 35.70us)         6
#     nlp_grad  |  79.00us ( 79.00us)  79.62us ( 79.62us)         1
#   nlp_grad_f  | 336.00us ( 48.00us) 339.57us ( 48.51us)         7
#   nlp_hess_l  | 424.00us ( 84.80us)   2.97ms (593.04us)         5
#    nlp_jac_g  | 358.00us ( 51.14us) 360.31us ( 51.47us)         7
#        total  |   7.96ms (  7.96ms)  14.68ms ( 14.68ms)         1
# Time 0.8
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  | 132.00us ( 22.00us) 132.91us ( 22.15us)         6
#        nlp_g  | 161.00us ( 26.83us) 203.20us ( 33.87us)         6
#     nlp_grad  | 133.00us (133.00us) 157.51us (157.51us)         1
#   nlp_grad_f  | 280.00us ( 40.00us) 387.60us ( 55.37us)         7
#   nlp_hess_l  | 175.00us ( 35.00us) 178.12us ( 35.62us)         5
#    nlp_jac_g  | 258.00us ( 36.86us) 292.64us ( 41.81us)         7
#        total  |   6.26ms (  6.26ms)  11.38ms ( 11.38ms)         1
# Time 1.0
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  | 170.00us ( 28.33us) 191.78us ( 31.96us)         6
#        nlp_g  | 181.00us ( 30.17us)  10.71ms (  1.79ms)         6
#     nlp_grad  |  71.00us ( 71.00us)  71.30us ( 71.30us)         1
#   nlp_grad_f  | 225.00us ( 32.14us) 222.29us ( 31.76us)         7
#   nlp_hess_l  | 274.00us ( 54.80us) 463.82us ( 92.76us)         5
#    nlp_jac_g  | 220.00us ( 31.43us) 222.40us ( 31.77us)         7
#        total  |   6.78ms (  6.78ms)  17.90ms ( 17.90ms)         1
# Time 1.2000000000000002
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  | 329.00us ( 54.83us)   1.25ms (207.68us)         6
#        nlp_g  | 278.00us ( 46.33us) 574.86us ( 95.81us)         6
#     nlp_grad  | 118.00us (118.00us) 118.51us (118.51us)         1
#   nlp_grad_f  | 410.00us ( 58.57us) 436.59us ( 62.37us)         7
#   nlp_hess_l  | 365.00us ( 73.00us) 371.42us ( 74.28us)         5
#    nlp_jac_g  | 388.00us ( 55.43us) 407.99us ( 58.28us)         7
#        total  |   9.90ms (  9.90ms)  26.59ms ( 26.59ms)         1
# Time 1.4000000000000001
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  | 306.00us ( 51.00us) 721.85us (120.31us)         6
#        nlp_g  | 278.00us ( 46.33us) 284.20us ( 47.37us)         6
#     nlp_grad  | 112.00us (112.00us) 110.12us (110.12us)         1
#   nlp_grad_f  | 366.00us ( 52.29us) 369.25us ( 52.75us)         7
#   nlp_hess_l  | 407.00us ( 81.40us) 464.65us ( 92.93us)         5
#    nlp_jac_g  | 373.00us ( 53.29us) 400.05us ( 57.15us)         7
#        total  |   9.79ms (  9.79ms)  11.54ms ( 11.54ms)         1
# Time 1.6
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  | 270.00us ( 45.00us) 272.19us ( 45.37us)         6
#        nlp_g  | 277.00us ( 46.17us) 283.54us ( 47.26us)         6
#     nlp_grad  |  90.00us ( 90.00us)  89.84us ( 89.84us)         1
#   nlp_grad_f  | 461.00us ( 65.86us) 526.20us ( 75.17us)         7
#   nlp_hess_l  | 430.00us ( 86.00us) 458.14us ( 91.63us)         5
#    nlp_jac_g  | 389.00us ( 55.57us) 394.53us ( 56.36us)         7
#        total  |  10.37ms ( 10.37ms)  11.61ms ( 11.61ms)         1
# Time 1.8
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  | 267.00us ( 44.50us) 269.32us ( 44.89us)         6
#        nlp_g  | 246.00us ( 41.00us) 240.59us ( 40.10us)         6
#     nlp_grad  |  89.00us ( 89.00us)  88.97us ( 88.97us)         1
#   nlp_grad_f  | 385.00us ( 55.00us) 393.69us ( 56.24us)         7
#   nlp_hess_l  | 419.00us ( 83.80us) 421.24us ( 84.25us)         5
#    nlp_jac_g  | 390.00us ( 55.71us) 394.38us ( 56.34us)         7
#        total  |   9.65ms (  9.65ms)  19.01ms ( 19.01ms)         1
# Time 2.0
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  | 231.00us ( 38.50us) 232.00us ( 38.67us)         6
#        nlp_g  | 266.00us ( 44.33us) 283.07us ( 47.18us)         6
#     nlp_grad  | 101.00us (101.00us) 101.09us (101.09us)         1
#   nlp_grad_f  | 370.00us ( 52.86us) 371.43us ( 53.06us)         7
#   nlp_hess_l  | 333.00us ( 66.60us) 336.61us ( 67.32us)         5
#    nlp_jac_g  | 352.00us ( 50.29us) 353.43us ( 50.49us)         7
#        total  |   9.36ms (  9.36ms)  10.54ms ( 10.54ms)         1
# Time 2.2
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  | 340.00us ( 56.67us) 345.24us ( 57.54us)         6
#        nlp_g  | 260.00us ( 43.33us) 262.62us ( 43.77us)         6
#     nlp_grad  |  96.00us ( 96.00us)  96.07us ( 96.07us)         1
#   nlp_grad_f  | 431.00us ( 61.57us) 555.15us ( 79.31us)         7
#   nlp_hess_l  | 416.00us ( 83.20us) 418.46us ( 83.69us)         5
#    nlp_jac_g  | 413.00us ( 59.00us) 419.37us ( 59.91us)         7
#        total  |  10.36ms ( 10.36ms)  11.17ms ( 11.17ms)         1
# Time 2.4000000000000004
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  | 138.00us ( 23.00us) 140.73us ( 23.46us)         6
#        nlp_g  | 160.00us ( 26.67us) 192.60us ( 32.10us)         6
#     nlp_grad  | 104.00us (104.00us)  98.28us ( 98.28us)         1
#   nlp_grad_f  | 299.00us ( 42.71us) 334.14us ( 47.73us)         7
#   nlp_hess_l  | 223.00us ( 44.60us) 225.26us ( 45.05us)         5
#    nlp_jac_g  | 218.00us ( 31.14us) 219.01us ( 31.29us)         7
#        total  |   6.20ms (  6.20ms)   6.43ms (  6.43ms)         1
# Time 2.6
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  | 145.00us ( 24.17us) 146.62us ( 24.44us)         6
#        nlp_g  | 162.00us ( 27.00us) 160.81us ( 26.80us)         6
#     nlp_grad  | 124.00us (124.00us) 167.84us (167.84us)         1
#   nlp_grad_f  | 249.00us ( 35.57us) 283.95us ( 40.56us)         7
#   nlp_hess_l  | 249.00us ( 49.80us) 254.70us ( 50.94us)         5
#    nlp_jac_g  | 237.00us ( 33.86us) 239.16us ( 34.17us)         7
#        total  |   6.65ms (  6.65ms)   7.01ms (  7.01ms)         1
# Time 2.8000000000000003
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  | 108.00us ( 18.00us) 108.96us ( 18.16us)         6
#        nlp_g  | 116.00us ( 19.33us) 115.29us ( 19.21us)         6
#     nlp_grad  |  70.00us ( 70.00us)  69.83us ( 69.83us)         1
#   nlp_grad_f  | 228.00us ( 32.57us) 250.35us ( 35.76us)         7
#   nlp_hess_l  | 190.00us ( 38.00us) 190.85us ( 38.17us)         5
#    nlp_jac_g  | 192.00us ( 27.43us) 215.30us ( 30.76us)         7
#        total  |   5.90ms (  5.90ms)   6.04ms (  6.04ms)         1
# Time 3.0
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  | 120.00us ( 20.00us) 127.66us ( 21.28us)         6
#        nlp_g  | 101.00us ( 16.83us) 102.74us ( 17.12us)         6
#     nlp_grad  |  74.00us ( 74.00us)  75.58us ( 75.58us)         1
#   nlp_grad_f  | 166.00us ( 23.71us) 170.56us ( 24.36us)         7
#   nlp_hess_l  | 185.00us ( 37.00us) 185.81us ( 37.16us)         5
#    nlp_jac_g  | 178.00us ( 25.43us) 180.13us ( 25.73us)         7
#        total  |   5.97ms (  5.97ms)   6.32ms (  6.32ms)         1
# Time 3.2
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  | 260.00us ( 28.89us) 273.83us ( 30.43us)         9
#        nlp_g  | 312.00us ( 34.67us) 369.71us ( 41.08us)         9
#     nlp_grad  |  67.00us ( 67.00us)  68.15us ( 68.15us)         1
#   nlp_grad_f  | 334.00us ( 33.40us) 336.62us ( 33.66us)        10
#   nlp_hess_l  | 505.00us ( 63.12us) 506.63us ( 63.33us)         8
#    nlp_jac_g  | 401.00us ( 40.10us) 949.24us ( 94.92us)        10
#        total  |  10.12ms ( 10.12ms)  11.41ms ( 11.41ms)         1
# Time 3.4000000000000004
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  | 117.00us ( 13.00us) 118.86us ( 13.21us)         9
#        nlp_g  | 109.00us ( 12.11us) 110.29us ( 12.25us)         9
#     nlp_grad  |  61.00us ( 61.00us)  61.77us ( 61.77us)         1
#   nlp_grad_f  | 208.00us ( 20.80us) 232.40us ( 23.24us)        10
#   nlp_hess_l  | 232.00us ( 29.00us) 235.21us ( 29.40us)         8
#    nlp_jac_g  | 221.00us ( 22.10us) 221.94us ( 22.19us)        10
#        total  |   7.48ms (  7.48ms)   7.65ms (  7.65ms)         1
# Time 3.6
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  | 146.00us ( 20.86us) 165.69us ( 23.67us)         7
#        nlp_g  | 141.00us ( 20.14us) 140.26us ( 20.04us)         7
#     nlp_grad  |  76.00us ( 76.00us)  74.02us ( 74.02us)         1
#   nlp_grad_f  | 183.00us ( 22.88us) 183.03us ( 22.88us)         8
#   nlp_hess_l  | 215.00us ( 35.83us) 215.19us ( 35.87us)         6
#    nlp_jac_g  | 209.00us ( 26.13us) 214.17us ( 26.77us)         8
#        total  |   6.76ms (  6.76ms)   6.93ms (  6.93ms)         1
# Time 3.8000000000000003
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  | 175.00us ( 29.17us) 223.67us ( 37.28us)         6
#        nlp_g  | 152.00us ( 25.33us) 152.03us ( 25.34us)         6
#     nlp_grad  |  65.00us ( 65.00us)  65.36us ( 65.36us)         1
#   nlp_grad_f  | 228.00us ( 32.57us) 231.98us ( 33.14us)         7
#   nlp_hess_l  | 342.00us ( 68.40us) 352.97us ( 70.59us)         5
#    nlp_jac_g  | 233.00us ( 33.29us) 237.22us ( 33.89us)         7
#        total  |   6.55ms (  6.55ms)   6.71ms (  6.71ms)         1
# Time 4.0
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  | 131.00us ( 18.71us) 132.57us ( 18.94us)         7
#        nlp_g  | 118.00us ( 16.86us) 118.22us ( 16.89us)         7
#     nlp_grad  |  75.00us ( 75.00us)  75.17us ( 75.17us)         1
#   nlp_grad_f  | 185.00us ( 23.12us) 184.73us ( 23.09us)         8
#   nlp_hess_l  | 233.00us ( 38.83us) 234.98us ( 39.16us)         6
#    nlp_jac_g  | 207.00us ( 25.88us) 208.00us ( 26.00us)         8
#        total  |   5.92ms (  5.92ms)   5.92ms (  5.92ms)         1
# Time 4.2
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  | 136.00us ( 15.11us) 136.99us ( 15.22us)         9
#        nlp_g  | 130.00us ( 14.44us) 133.08us ( 14.79us)         9
#     nlp_grad  |  56.00us ( 56.00us)  56.85us ( 56.85us)         1
#   nlp_grad_f  | 256.00us ( 25.60us) 253.40us ( 25.34us)        10
#   nlp_hess_l  | 228.00us ( 28.50us) 228.51us ( 28.56us)         8
#    nlp_jac_g  | 243.00us ( 24.30us) 245.70us ( 24.57us)        10
#        total  |   7.68ms (  7.68ms)   7.72ms (  7.72ms)         1
# Time 4.4
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |  93.00us ( 13.29us) 124.48us ( 17.78us)         7
#        nlp_g  |  99.00us ( 14.14us)  99.43us ( 14.20us)         7
#     nlp_grad  |  56.00us ( 56.00us)  56.14us ( 56.14us)         1
#   nlp_grad_f  | 185.00us ( 23.12us) 186.11us ( 23.26us)         8
#   nlp_hess_l  | 179.00us ( 29.83us) 179.19us ( 29.87us)         6
#    nlp_jac_g  | 189.00us ( 23.63us) 189.04us ( 23.63us)         8
#        total  |   6.05ms (  6.05ms)   6.14ms (  6.14ms)         1
# Time 4.6000000000000005
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |  82.00us ( 11.71us)  81.28us ( 11.61us)         7
#        nlp_g  |  81.00us ( 11.57us)  78.24us ( 11.18us)         7
#     nlp_grad  |  84.00us ( 84.00us)  90.58us ( 90.58us)         1
#   nlp_grad_f  | 138.00us ( 17.25us) 140.68us ( 17.59us)         8
#   nlp_hess_l  | 150.00us ( 25.00us) 151.09us ( 25.18us)         6
#    nlp_jac_g  | 162.00us ( 20.25us) 164.37us ( 20.55us)         8
#        total  |   5.48ms (  5.48ms)   5.48ms (  5.48ms)         1
# Time 4.800000000000001
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |  99.00us ( 14.14us)  97.93us ( 13.99us)         7
#        nlp_g  |  86.00us ( 12.29us) 129.21us ( 18.46us)         7
#     nlp_grad  |  60.00us ( 60.00us)  60.26us ( 60.26us)         1
#   nlp_grad_f  | 149.00us ( 18.62us) 149.81us ( 18.73us)         8
#   nlp_hess_l  | 170.00us ( 28.33us) 202.49us ( 33.75us)         6
#    nlp_jac_g  | 174.00us ( 21.75us) 176.70us ( 22.09us)         8
#        total  |   5.91ms (  5.91ms)   5.98ms (  5.98ms)         1
# Time 5.0
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  | 100.00us ( 14.29us)  99.06us ( 14.15us)         7
#        nlp_g  | 117.00us ( 16.71us) 123.61us ( 17.66us)         7
#     nlp_grad  |  60.00us ( 60.00us)  60.39us ( 60.39us)         1
#   nlp_grad_f  | 168.00us ( 21.00us) 168.03us ( 21.00us)         8
#   nlp_hess_l  | 241.00us ( 40.17us) 256.98us ( 42.83us)         6
#    nlp_jac_g  | 195.00us ( 24.38us) 195.76us ( 24.47us)         8
#        total  |   6.27ms (  6.27ms)   6.39ms (  6.39ms)         1
# Time 5.2
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  | 148.00us ( 21.14us) 160.53us ( 22.93us)         7
#        nlp_g  | 161.00us ( 23.00us) 166.11us ( 23.73us)         7
#     nlp_grad  |  61.00us ( 61.00us)  60.97us ( 60.97us)         1
#   nlp_grad_f  | 256.00us ( 32.00us) 265.90us ( 33.24us)         8
#   nlp_hess_l  | 256.00us ( 42.67us) 257.99us ( 43.00us)         6
#    nlp_jac_g  | 255.00us ( 31.88us) 295.46us ( 36.93us)         8
#        total  |   7.55ms (  7.55ms)   7.85ms (  7.85ms)         1
# Time 5.4
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  | 158.00us ( 22.57us) 165.33us ( 23.62us)         7
#        nlp_g  | 179.00us ( 25.57us) 196.05us ( 28.01us)         7
#     nlp_grad  |  98.00us ( 98.00us) 101.82us (101.82us)         1
#   nlp_grad_f  | 194.00us ( 24.25us) 196.42us ( 24.55us)         8
#   nlp_hess_l  | 273.00us ( 45.50us) 280.32us ( 46.72us)         6
#    nlp_jac_g  | 249.00us ( 31.12us) 265.91us ( 33.24us)         8
#        total  |   7.65ms (  7.65ms)   7.97ms (  7.97ms)         1
# Time 5.6000000000000005
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |  99.00us ( 14.14us)  98.61us ( 14.09us)         7
#        nlp_g  | 111.00us ( 15.86us) 126.97us ( 18.14us)         7
#     nlp_grad  |  78.00us ( 78.00us)  79.73us ( 79.73us)         1
#   nlp_grad_f  | 165.00us ( 20.63us) 165.57us ( 20.70us)         8
#   nlp_hess_l  | 162.00us ( 27.00us) 163.05us ( 27.17us)         6
#    nlp_jac_g  | 193.00us ( 24.12us) 192.19us ( 24.02us)         8
#        total  |   6.02ms (  6.02ms)   6.09ms (  6.09ms)         1
# Time 5.800000000000001
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |  95.00us ( 13.57us) 134.94us ( 19.28us)         7
#        nlp_g  |  92.00us ( 13.14us)  91.70us ( 13.10us)         7
#     nlp_grad  |  79.00us ( 79.00us)  87.19us ( 87.19us)         1
#   nlp_grad_f  | 169.00us ( 21.12us) 168.20us ( 21.03us)         8
#   nlp_hess_l  | 205.00us ( 34.17us) 207.53us ( 34.59us)         6
#    nlp_jac_g  | 195.00us ( 24.38us) 203.03us ( 25.38us)         8
#        total  |   6.35ms (  6.35ms)   6.51ms (  6.51ms)         1
# Time 6.0
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  | 115.00us ( 16.43us) 118.36us ( 16.91us)         7
#        nlp_g  | 110.00us ( 15.71us) 109.90us ( 15.70us)         7
#     nlp_grad  |  69.00us ( 69.00us)  73.57us ( 73.57us)         1
#   nlp_grad_f  | 203.00us ( 25.38us) 203.21us ( 25.40us)         8
#   nlp_hess_l  | 186.00us ( 31.00us) 186.21us ( 31.03us)         6
#    nlp_jac_g  | 199.00us ( 24.88us) 201.26us ( 25.16us)         8
#        total  |   6.49ms (  6.49ms)   6.64ms (  6.64ms)         1
# Time 6.2
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  | 175.00us ( 21.88us) 179.70us ( 22.46us)         8
#        nlp_g  | 151.00us ( 18.88us) 154.58us ( 19.32us)         8
#     nlp_grad  |  75.00us ( 75.00us)  75.36us ( 75.36us)         1
#   nlp_grad_f  | 230.00us ( 25.56us) 232.34us ( 25.82us)         9
#   nlp_hess_l  | 329.00us ( 47.00us) 338.46us ( 48.35us)         7
#    nlp_jac_g  | 246.00us ( 27.33us) 250.97us ( 27.89us)         9
#        total  |   7.71ms (  7.71ms)   7.80ms (  7.80ms)         1
# Time 6.4
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  | 128.00us ( 16.00us) 126.79us ( 15.85us)         8
#        nlp_g  | 149.00us ( 18.63us) 148.96us ( 18.62us)         8
#     nlp_grad  |  66.00us ( 66.00us)  65.81us ( 65.81us)         1
#   nlp_grad_f  | 210.00us ( 23.33us) 208.55us ( 23.17us)         9
#   nlp_hess_l  | 268.00us ( 38.29us) 269.13us ( 38.45us)         7
#    nlp_jac_g  | 239.00us ( 26.56us) 237.54us ( 26.39us)         9
#        total  |   6.73ms (  6.73ms)   6.72ms (  6.72ms)         1
# Time 6.6000000000000005
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  | 116.00us ( 14.50us) 114.92us ( 14.36us)         8
#        nlp_g  | 121.00us ( 15.12us) 152.62us ( 19.08us)         8
#     nlp_grad  |  71.00us ( 71.00us)  71.22us ( 71.22us)         1
#   nlp_grad_f  | 190.00us ( 21.11us) 188.48us ( 20.94us)         9
#   nlp_hess_l  | 223.00us ( 31.86us) 223.79us ( 31.97us)         7
#    nlp_jac_g  | 225.00us ( 25.00us) 227.93us ( 25.33us)         9
#        total  |   6.56ms (  6.56ms)   6.57ms (  6.57ms)         1
# Time 6.800000000000001
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  | 130.00us ( 16.25us) 130.10us ( 16.26us)         8
#        nlp_g  | 130.00us ( 16.25us) 131.31us ( 16.41us)         8
#     nlp_grad  |  94.00us ( 94.00us)  93.54us ( 93.54us)         1
#   nlp_grad_f  | 218.00us ( 24.22us) 219.43us ( 24.38us)         9
#   nlp_hess_l  | 227.00us ( 32.43us) 227.53us ( 32.50us)         7
#    nlp_jac_g  | 255.00us ( 28.33us) 257.45us ( 28.61us)         9
#        total  |   6.96ms (  6.96ms)   7.02ms (  7.02ms)         1
# Time 7.0
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  | 139.00us ( 17.37us) 141.87us ( 17.73us)         8
#        nlp_g  | 148.00us ( 18.50us) 147.09us ( 18.39us)         8
#     nlp_grad  |  66.00us ( 66.00us)  66.35us ( 66.35us)         1
#   nlp_grad_f  | 256.00us ( 28.44us) 256.42us ( 28.49us)         9
#   nlp_hess_l  | 353.00us ( 50.43us) 354.02us ( 50.57us)         7
#    nlp_jac_g  | 243.00us ( 27.00us) 247.68us ( 27.52us)         9
#        total  |   7.44ms (  7.44ms)   7.48ms (  7.48ms)         1
# Time 7.2
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  | 209.00us ( 23.22us) 212.67us ( 23.63us)         9
#        nlp_g  | 231.00us ( 25.67us) 231.29us ( 25.70us)         9
#     nlp_grad  |  82.00us ( 82.00us)  83.77us ( 83.77us)         1
#   nlp_grad_f  | 355.00us ( 35.50us) 376.10us ( 37.61us)        10
#   nlp_hess_l  | 320.00us ( 40.00us) 325.79us ( 40.72us)         8
#    nlp_jac_g  | 313.00us ( 31.30us) 315.56us ( 31.56us)        10
#        total  |   8.71ms (  8.71ms)   8.85ms (  8.85ms)         1
# Time 7.4
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  | 147.00us ( 13.36us) 148.30us ( 13.48us)        11
#        nlp_g  | 143.00us ( 13.00us) 143.04us ( 13.00us)        11
#     nlp_grad  |  63.00us ( 63.00us)  63.80us ( 63.80us)         1
#   nlp_grad_f  | 258.00us ( 21.50us) 256.45us ( 21.37us)        12
#   nlp_hess_l  | 300.00us ( 30.00us) 345.41us ( 34.54us)        10
#    nlp_jac_g  | 275.00us ( 22.92us) 276.87us ( 23.07us)        12
#        total  |   8.87ms (  8.87ms)   9.01ms (  9.01ms)         1
# Time 7.6000000000000005
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  | 128.00us ( 14.22us) 129.50us ( 14.39us)         9
#        nlp_g  | 146.00us ( 16.22us) 145.88us ( 16.21us)         9
#     nlp_grad  |  75.00us ( 75.00us)  74.94us ( 74.94us)         1
#   nlp_grad_f  | 266.00us ( 26.60us) 311.99us ( 31.20us)        10
#   nlp_hess_l  | 304.00us ( 38.00us) 304.53us ( 38.07us)         8
#    nlp_jac_g  | 246.00us ( 24.60us) 246.28us ( 24.63us)        10
#        total  |   7.75ms (  7.75ms)   7.82ms (  7.82ms)         1

# %%
L = Cars[0].X_hist[0,:].shape[0]

X_hist = np.zeros((2,3,L))
for i in range(2):
    X_hist[i,0,:] = Cars[i].X_hist[0,:]
    X_hist[i,1,:] = Cars[i].X_hist[1,:]
    X_hist[i,2,:-1] = Cars[i].U_hist

# %%
t_series = T*np.linspace(0,L-1,num=L)
# %matplotlib inline
for i in range(2):
    plt.plot(t_series, X_hist[i,0,:], label = "Vehicle " + str(i))
plt.grid()
plt.legend(loc="upper left")
plt.xlabel('Time (s)')
plt.ylabel('Position (m)')
# Out:
# Text(0, 0.5, 'Position (m)')

# %%
for i in range(2):
    plt.plot(t_series, X_hist[i,1,:], label = "Vehicle " + str(i))
plt.grid()
plt.legend(loc="upper left")
plt.xlabel('Time (s)')
plt.ylabel('Speed (m/s)')
# Out:
# Text(0, 0.5, 'Speed (m/s)')

# %%
def distance(p1, p2, angle):
    if p2 <= 0:
        dist = np.sqrt(p1**2 + p2**2 - 2*np.cos(angle)*p1*p2)
    elif p2 > 0:
        dist = np.abs(p1-p2)
    return dist
d = np.zeros(L)
for i in range(L):
    p1 = X_hist[0,0,i]; p2 = X_hist[1,0,i]
    d[i] = distance(p1, p2, np.pi/6)

# %%
plt.plot(t_series, d, label = "Vehicle " + str(i))
plt.grid()
plt.xlabel('Time (s)')
plt.ylabel('Distance (m)')
# Out:
# Text(0, 0.5, 'Distance (m)')
